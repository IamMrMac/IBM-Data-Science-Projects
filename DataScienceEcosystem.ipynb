# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# * In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# * Objectives:*
# - Task a data scientist need to perform
# - Data Sicience languages
# - Commercial tools
# - Data science on cloud

# %% [markdown]
# Some of the commonly used Data Science Languages include;
# 1. Python.
# 2. R.
# 3. SQL.
# 4. Java.
# 5. Julia.
# 6. Scala.

# %% [markdown]
# Some of commonly used Data Science libraries include;
# 1. TensorFlow
# 2. SciKit Learn
# 3. Pytorch
# 4. Pandas

# %% [markdown]
# | Data Science Tools |
# | -------- |
# | RStudio.|
# | Apache Spark  |
# | TensorFlow. |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Samuel Onyebuchi Nwachukwu
