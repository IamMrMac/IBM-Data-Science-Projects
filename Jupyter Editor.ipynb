# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SAMUEL NWACHUKWU**
# DATA ENGINEER

# %% [markdown]
# *I am interested in Data Science because it is considered the sexiest job of the 21st century. It also offers me the opportunity to make informed decisions using data*

# %% [markdown]
# ### The code below calculates the sum of numbers

# %%
2+3+18
# Out:
# 23

# %% [markdown]
# - come check this out
# 1. Below is a pictorial representation of Data Analytics
# 2. It shows all the many data points of a project
# ![data-analytics.jpg](attachment:data-analytics.jpg)
